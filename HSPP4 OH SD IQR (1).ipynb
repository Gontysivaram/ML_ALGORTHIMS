# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("C:\\Users\\Vivek\\OneDrive\\Desktop\\81 column dataset.csv")

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe(include="all").T
# Out:
#                 count unique     top  freq          mean           std  \
# Id             1460.0    NaN     NaN   NaN         730.5    421.610009
# MSSubClass     1460.0    NaN     NaN   NaN      56.89726     42.300571
# MSZoning         1460      5      RL  1151           NaN           NaN
# LotFrontage    1201.0    NaN     NaN   NaN     70.049958     24.284752
# LotArea        1460.0    NaN     NaN   NaN  10516.828082   9981.264932
# ...               ...    ...     ...   ...           ...           ...
# MoSold         1460.0    NaN     NaN   NaN      6.321918      2.703626
# YrSold         1460.0    NaN     NaN   NaN   2007.815753      1.328095
# SaleType         1460      9      WD  1267           NaN           NaN
# SaleCondition    1460      6  Normal  1198           NaN           NaN
# SalePrice      1460.0    NaN     NaN   NaN  180921.19589  79442.502883
#
#                    min       25%       50%       75%       max
# ...

# %%
df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
print(f"Total columns with null values:{(lambda x:(len(x),x))(df.isnull().sum()[df.isnull().sum() > 0])}")
# Out:
# Total columns with null values:(19, LotFrontage      259
# Alley           1369
# MasVnrType       872
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64)

# %%
df.isnull().sum()/len(df)*100
# Out:
# Id                0.000000
# MSSubClass        0.000000
# MSZoning          0.000000
# LotFrontage      17.739726
# LotArea           0.000000
#                    ...
# MoSold            0.000000
# YrSold            0.000000
# SaleType          0.000000
# SaleCondition     0.000000
# SalePrice         0.000000
# Length: 81, dtype: float64

# %%
from feature_engine.imputation import CategoricalImputer

# %%
cat_columns=df.select_dtypes(include='object').columns

# %%
cat_columns
# Out:
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
num_columns=df.select_dtypes(include='number').columns

# %%
num_columns
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal', 'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# Fill numerical columns with median
numerical_cols = df.select_dtypes(include=['float64', 'int64']).columns

for i in numerical_cols:
    df[i].fillna(df[i].median(),inplace=True)
# Out:
# C:\Users\Vivek\AppData\Local\Temp\ipykernel_12828\695000996.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[i].fillna(df[i].median(),inplace=True)

# %%
# Fill categorical columns with mode
categorical_cols = df.select_dtypes(include=['object']).columns

for i in categorical_cols:
     df[i].fillna(df[i].mode()[0],inplace=True)
# Out:
# C:\Users\Vivek\AppData\Local\Temp\ipykernel_12828\1218372141.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[i].fillna(df[i].mode()[0],inplace=True)

# %%
print(f"Total columns with null values:{(lambda x:(len(x),x))(df.isnull().sum()[df.isnull().sum() > 0])}")
# Out:
# Total columns with null values:(0, Series([], dtype: int64))

# %%
df.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 81, dtype: int64

# %%
for col in df.select_dtypes(include="number").columns:
  sns.boxplot(df[col])
  plt.show()

# %%
def wisker(col):
   q1=df[col].quantile(0.25)
   q3=df[col].quantile(0.75)
   iqr=q3-q1
   lower=q1-(1.5*iqr)
   upper=q3+(1.5*iqr)
   return lower,upper

# %%
for col in df.select_dtypes(include=['number']).columns:
    lower,upper=wisker(col)
    df[i]=np.where(df[i]<lower,lower,df[i])   
    df[i]=np.where(df[i]>upper,upper,df[i])

# %%
for i in df.select_dtypes(include=['number']).columns:
    sns.boxplot(df[i])
    plt.show()

# %%
from sklearn.preprocessing import OneHotEncoder
one_hot=OneHotEncoder()
for col in cat_columns:
    df2 = pd.get_dummies(df, columns=cat_columns, drop_first=True, dtype="int32")


df2
# Out:
#           Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0     3937.5          60         65.0     8450            7            5
# 1     3937.5          20         80.0     9600            6            8
# 2     3937.5          60         68.0    11250            7            5
# 3     3937.5          70         60.0     9550            7            5
# 4     3937.5          60         84.0    14260            8            5
# ...      ...         ...          ...      ...          ...          ...
# 1455  3937.5          60         62.0     7917            6            5
# 1456  3937.5          20         85.0    13175            6            6
# 1457  3937.5          70         66.0     9042            7            9
# 1458  3937.5          20         68.0     9717            5            6
# 1459  3937.5          20         75.0     9937            5            6
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  SaleType_ConLI  \
# ...

# %%
from sklearn.preprocessing import StandardScaler
stand_scl = StandardScaler()
data2[num_columns] = stand_scl.fit_transform(data2[num_columns])
